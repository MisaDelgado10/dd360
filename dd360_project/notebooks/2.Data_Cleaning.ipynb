# %%
# !pip install -qq pandas numpy pyarrow

# %% [markdown]
# # Objetivo
#
# El objetivo principal de este notebook es usar los métodos del archivo transform.py para preprocesar y transformar el conjunto de datos inmobiliarios de forma cuidadosa, asegurando que todas las variables relevantes estén en un formato limpio, consistente y analizable sin eliminar información valiosa (ya que el dataset de por sí ya es pequeño con alrededor de 4k filas). Esto permite mejorar la calidad de los datos para análisis posteriores y la generación de comparables inmobiliarios.
#
# Insights:
#
# 1. Estandarización de columnas categóricas
#
# 2. Imputación de valores faltantes en variables numéricas
#
# 3. Manejo de columnas binarias
#
# 4. Tratamiento de outliers extremos (sin eliminarlos)
#
# 5. Conversión de columnas numéricas a tipos enteros

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/cuahutemoc_properties.csv")

# %%
import sys
from pathlib import Path

project_root = Path().resolve().parent
sys.path.append(str(project_root))

# %%
from dd360.transform import clean_property_data

# %%
df_clean = clean_property_data(df)

# %%
df_clean.head()
# Out:
#                                  listing_type property_type  \
# property_id
# 5ae456983ab717ec68e1ff2e0689c5d8     for-sale     apartment
# fff8db1482a59a1c9093f9ab3ac50ddf     for-sale     apartment
# 7f0478d4f668aaf45ed3511523746fce     for-sale     apartment
# 4a0034cf7bfdd9b610bcb4a2e5096cf0     for-sale     apartment
# afdc70d7a521ba91cc026062653fe841     for-sale     apartment
#
#                                                                              url_ad  \
# property_id
# 5ae456983ab717ec68e1ff2e0689c5d8  https://rentahouse.com.mx/departamento_en_vent...
# fff8db1482a59a1c9093f9ab3ac50ddf  https://www.easybroker.com/mx/listings/departa...
# 7f0478d4f668aaf45ed3511523746fce  https://www.vivanuncios.com.mx/a-venta-departa...
# 4a0034cf7bfdd9b610bcb4a2e5096cf0  https://www.clau.com/propiedades/3pm-departame...
# afdc70d7a521ba91cc026062653fe841  https://degohouse.com.mx/apartamento-venta-non...
#
#                                        price  terrain_surface  \
# property_id
# 5ae456983ab717ec68e1ff2e0689c5d8   9348347.0            260.0
# fff8db1482a59a1c9093f9ab3ac50ddf  16200000.0            244.5
# 7f0478d4f668aaf45ed3511523746fce   5400000.0            244.5
# 4a0034cf7bfdd9b610bcb4a2e5096cf0   6700000.0            194.5
# afdc70d7a521ba91cc026062653fe841   3778408.0            200.0
#
#                                   construction_surface  num_bathrooms  \
# property_id
# 5ae456983ab717ec68e1ff2e0689c5d8                  96.0              2
# fff8db1482a59a1c9093f9ab3ac50ddf                  90.0              2
# 7f0478d4f668aaf45ed3511523746fce                 110.0              1
# 4a0034cf7bfdd9b610bcb4a2e5096cf0                  79.0              2
# afdc70d7a521ba91cc026062653fe841                  67.0              2
#
#                                   num_parking_lots  num_bedrooms  built_year  \
# property_id
# 5ae456983ab717ec68e1ff2e0689c5d8                 1             1        2024
# fff8db1482a59a1c9093f9ab3ac50ddf                 1             2        2025
# 7f0478d4f668aaf45ed3511523746fce                 1             2        1999
# 4a0034cf7bfdd9b610bcb4a2e5096cf0                 0             2        2000
# afdc70d7a521ba91cc026062653fe841                 1             2        2019
#
#                                   conservation_status   latitude  longitude  \
# property_id
# 5ae456983ab717ec68e1ff2e0689c5d8             0.989510  19.430419 -99.163761
# fff8db1482a59a1c9093f9ab3ac50ddf             0.981774  19.425804 -99.167429
# 7f0478d4f668aaf45ed3511523746fce             0.916711  19.426753 -99.161845
# 4a0034cf7bfdd9b610bcb4a2e5096cf0             0.873144  19.422017 -99.164724
# afdc70d7a521ba91cc026062653fe841             0.988560  19.432608 -99.133208
#
#                                   id_neighborhood neighborhood  has_garden  \
# property_id
# 5ae456983ab717ec68e1ff2e0689c5d8            11817   CUAUHTEMOC           1
# fff8db1482a59a1c9093f9ab3ac50ddf            11818       JUAREZ           0
# 7f0478d4f668aaf45ed3511523746fce            11818       JUAREZ           0
# 4a0034cf7bfdd9b610bcb4a2e5096cf0            11819   ROMA NORTE           0
# afdc70d7a521ba91cc026062653fe841            11800       CENTRO           0
#
#                                   has_gym
# property_id
# 5ae456983ab717ec68e1ff2e0689c5d8        0
# fff8db1482a59a1c9093f9ab3ac50ddf        1
# 7f0478d4f668aaf45ed3511523746fce        0
# 4a0034cf7bfdd9b610bcb4a2e5096cf0        0
# afdc70d7a521ba91cc026062653fe841        0

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4513 entries, 5ae456983ab717ec68e1ff2e0689c5d8 to 3cd6ac47327af734a867e646a8637e56
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   listing_type          4513 non-null   object
#  1   property_type         4513 non-null   object
#  2   url_ad                4513 non-null   object
#  3   price                 4513 non-null   float64
#  4   terrain_surface       4513 non-null   float64
#  5   construction_surface  4513 non-null   float64
#  6   num_bathrooms         4513 non-null   int64
#  7   num_parking_lots      4513 non-null   int64
#  8   num_bedrooms          4513 non-null   int64
#  9   built_year            4513 non-null   int64
#  10  conservation_status   4513 non-null   float64
#  11  latitude              4513 non-null   float64
#  12  longitude             4513 non-null   float64
#  13  id_neighborhood       4513 non-null   int64
#  14  neighborhood          4513 non-null   object
#  15  has_garden            4513 non-null   int64
#  16  has_gym               4513 non-null   int64
# dtypes: float64(6), int64(7), object(4)
# memory usage: 634.6+ KB

# %%
df_clean.reset_index().to_parquet('../data/interim/cleaned.parquet', index = False)
